# %% [markdown]
# ### ls명령어로 현재 폴더에 Salaries.csv파일이 있는지 확인

# %%
ls
# Out:
# F9문제.ipynb    Salaries.csv    Untitled.ipynb

# %% [markdown]
# ### import 정리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 데이터 불러오기

# %%
data = pd.read_csv('Salaries.csv')
print(data.shape)
# Out:
# (148654, 13)
# /var/folders/sw/ypsqlfts35lf8nn7vytq_t100000gn/T/ipykernel_7664/3001703172.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Salaries.csv')

# %% [markdown]
# ### x축, y축 설정
# * data의 TotalPay(OvertimePay 아님 ㅎ)를 년도별 평균을 내어 y에 저장(4개 숫자)
# * data의 Year를 x에 저장(4개 숫자)

# %%
mean= data['TotalPay'].groupby(data['Year']).mean()
print(mean)

y = mean.values
print(y)
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64
# [71744.10387124 74113.26226514 77611.44314205 75463.91814023]

# %% [markdown]
# ### x 확인

# %%
x
# Out:
# Index(['2011', '2012', '2013', '2014'], dtype='object', name='Year')

# %% [markdown]
# ### y 확인

# %%
y
# Out:
# array([71744.10387124, 74113.26226514, 77611.44314205, 75463.91814023])

# %% [markdown]
# ### matplotlib, seaborn을 이용하여 각각 barplot을 그려보자
# * 결과물이 다음 그래프와 동일하게 나와야 함
# * 1번(plt)의 그래프 색은 빨강, 파랑, 분홍, 초록이며, 2번(sns)의 그래프 색은 twilight(palette설정 검색)
# * 그래프 크기도 조절하여 최대한 맞춰볼 것

# %%
fig = plt.figure(figsize = (15,7))

ax1 = fig.add_subplot(1,2,1)
colors = ['red','blue','pink','green']
ax1.bar(x=x,height=y,color=colors)

ax2 = fig.add_subplot(1,2,2)
sns.barplot(data = data, x = x, y = y, palette = "twilight")
plt.ylabel('TotalPay')
plt.show()
